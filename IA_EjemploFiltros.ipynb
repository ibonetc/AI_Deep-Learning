# %% [markdown]
# <a href="https://colab.research.google.com/github/ibonetc/AI_Deep-Learning/blob/main/IA_EjemploFiltros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
import scipy
from scipy import signal
import matplotlib.pyplot as plt

# %% [markdown]
# # Filtro para buscar bordes

# %%
path='/content/drive/MyDrive/Fotos_Pruebas/cisnes.jpg'

# %%
img=cv2.imread(path)
img.shape
# Out:
# (2988, 5312, 3)

# %%
img=cv2.cvtColor(src=img, code=cv2.COLOR_BGR2GRAY) ## Convertir a blanco y negro
imgR=cv2.resize(img,(500,500)) ## Para achicar la imagen un poco
cv2_imshow(imgR)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7F465D173950>

# %%
kernel=np.array([[-1,-1,-1],[-1,8,-1],[-1,-1,-1]])
kernel
# Out:
# array([[-1, -1, -1],
#        [-1,  8, -1],
#        [-1, -1, -1]])

# %%
img

# %%
res=signal.convolve2d(imgR, kernel, mode='same', boundary='fill', fillvalue=0)

# %%
cv2_imshow(res)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7FF1CCC5A390>

# %%
kernel=np.array([[1,0,-1],[2,0,-2],[1,0,-1]])
res=signal.convolve2d(imgR, kernel, mode='same', boundary='fill', fillvalue=0)
cv2_imshow(res)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7FF1CCC41510>

# %%
kernel=kernel/(np.sum(kernel) if np.sum(kernel)!=0 else 1)
res=cv2.filter2D(imgR, -1,kernel)
cv2_imshow(res)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7FF1CCC41B50>

# %%
kernel=np.array([[1,1,1],[0,0,0],[-1,-1,-1]])
res=signal.convolve2d(imgR, kernel, mode='same', boundary='fill', fillvalue=0)
cv2_imshow(res)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7FF1CCCC6910>

# %%
img=cv2.imread(path)
img=cv2.cvtColor(src=img,code=cv2.COLOR_BGR2RGB)
imgR=cv2.resize(img,(500,500))
plt.figure(figsize=(10,10))
plt.imshow(imgR)
plt.show()

# %%
kernel=np.array([[1,0,-1],[2,0,-2],[1,0,-1]])
res=cv2.filter2D(imgR, -1,kernel)
plt.figure(figsize=(10,10))
plt.imshow(res)
plt.show()
