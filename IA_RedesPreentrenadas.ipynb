# %% [markdown]
# <a href="https://colab.research.google.com/github/ibonetc/AI_Deep-Learning/blob/main/IA_RedesPreentrenadas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.applications.vgg16 import VGG16,decode_predictions
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from keras.models import Model
from numpy import expand_dims
from matplotlib import pyplot as plt
import numpy as np

# %%
img = load_img('/content/drive/MyDrive/Fotos_Pruebas/cisneNegro.jpg', target_size=(224, 224))
plt.imshow(img)

# %%
fileImage='/content/drive/MyDrive/Fotos_Pruebas/cisneNegro.jpg'
img = load_img(fileImage, target_size=(224, 224))
img = img_to_array(img)
img = expand_dims(img, axis=0)
img = preprocess_input(img)

# %%
model_vgg16 = VGG16(weights="imagenet")

# %%
preds=model_vgg16.predict(img)
decode_predictions(preds, top=3)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# [[('n01698640', 'American_alligator', np.float32(0.13971667)),
#   ('n01737021', 'water_snake', np.float32(0.075219475)),
#   ('n01860187', 'black_swan', np.float32(0.05518494))]]

# %%
from tensorflow.keras.applications.vgg19 import VGG19,preprocess_input,decode_predictions

# %%
model_vgg19=VGG19(weights='imagenet')

# %%
img=load_img(fileImage,target_size=(224,224))
x=img_to_array(img)
x=expand_dims(x,axis=0)
x=preprocess_input(x)

# %%
y=model_vgg19.predict(x)
decode_predictions(y, top=3)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# [[('n01860187', 'black_swan', np.float32(0.12138019)),
#   ('n01698640', 'American_alligator', np.float32(0.07248651)),
#   ('n02099429', 'curly-coated_retriever', np.float32(0.064738534))]]

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3,preprocess_input,decode_predictions

# %%
model_inception=InceptionV3(weights='imagenet')

# %%
img=load_img(fileImage,target_size=(299,299))
x=img_to_array(img)
x=expand_dims(x,axis=0)
x=preprocess_input(x)

# %%
y=model_inception.predict(x)
decode_predictions(y, top=3)
# Out:
# WARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x79ed5d509a80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# [[('n01860187', 'black_swan', np.float32(0.33862263)),
#   ('n02037110', 'oystercatcher', np.float32(0.12731786)),
#   ('n02018207', 'American_coot', np.float32(0.046181098))]]
