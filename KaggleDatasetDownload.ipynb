# %% [markdown]
# <a href="https://colab.research.google.com/github/ibonetc/AI_Deep-Learning/blob/main/KaggleDatasetDownload.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q kaggle

# %%
from google.colab import files

# %%
#Crear fichero kaggle en raíz
# !mkdir ~/.kaggle

# %%
#Copiar el fichero .json que descargamos en esta carpeta
# !cp /content/drive/MyDrive/_Credentials/kaggle.json ~/.kaggle/

# %%
#Cambiar permisos del fichero
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d paultimothymooney/breast-histopathology-images
# Out:
# ...
#  99% 3.07G/3.10G [00:25<00:00, 161MB/s]
# 100% 3.10G/3.10G [00:25<00:00, 129MB/s]

# %%
# !kaggle competitions download -c dogs-vs-cats-redux-kernels-edition
# Out:
# ...
#  98% 800M/814M [00:08<00:00, 106MB/s]
# 100% 814M/814M [00:08<00:00, 102MB/s]

# %%
# !unzip /content/dogs-vs-cats-redux-kernels-edition.zip
# Out:
# Archive:  /content/dogs-vs-cats-redux-kernels-edition.zip
#   inflating: sample_submission.csv
#   inflating: test.zip
#   inflating: train.zip

# %%
# !unzip /content/train.zip

# %%
import os
os.listdir('/content/train')
# Out:
# ['cat.11103.jpg',
#  'cat.6702.jpg',
#  'dog.462.jpg',
#  'dog.3374.jpg',
#  'dog.9239.jpg',
#  'cat.5546.jpg',
#  'cat.2970.jpg',
#  'cat.2772.jpg',
#  'dog.4101.jpg',
#  'cat.4690.jpg',
#  'cat.7356.jpg',
#  'cat.7504.jpg',
#  'dog.2918.jpg',
#  'dog.4816.jpg',
#  'dog.519.jpg',
#  'cat.3600.jpg',
#  'dog.11642.jpg',
#  'cat.6855.jpg',
#  'cat.9058.jpg',
#  'dog.6593.jpg',
#  'cat.339.jpg',
#  'dog.5337.jpg',
#  'cat.6334.jpg',
#  'dog.2619.jpg',
#  'dog.7291.jpg',
#  'cat.1396.jpg',
#  'dog.3149.jpg',
#  'cat.8002.jpg',
#  'dog.10894.jpg',
#  'dog.5279.jpg',
#  'dog.11247.jpg',
#  'dog.4968.jpg',
#  'cat.377.jpg',
#  'cat.11252.jpg',
#  'dog.10060.jpg',
#  'dog.2387.jpg',
#  'dog.11751.jpg',
#  'dog.9321.jpg',
#  'dog.5202.jpg',
#  'cat.11262.jpg',
#  'cat.11660.jpg',
#  'dog.9783.jpg',
#  'dog.2157.jpg',
#  'dog.4740.jpg',
#  'cat.2080.jpg',
#  'dog.1904.jpg',
#  'dog.2519.jpg',
#  'cat.10377.jpg',
#  'dog.6011.jpg',
#  'cat.2177.jpg',
#  'cat.3326.jpg',
#  'cat.7367.jpg',
# ...

# %%
import glob
import numpy as np

# %%
data_dog_cat = glob.glob("/content/train/*.jpg")
data_dog_cat
# Out:
# ['/content/train/cat.11103.jpg',
#  '/content/train/cat.6702.jpg',
#  '/content/train/dog.462.jpg',
#  '/content/train/dog.3374.jpg',
#  '/content/train/dog.9239.jpg',
#  '/content/train/cat.5546.jpg',
#  '/content/train/cat.2970.jpg',
#  '/content/train/cat.2772.jpg',
#  '/content/train/dog.4101.jpg',
#  '/content/train/cat.4690.jpg',
#  '/content/train/cat.7356.jpg',
#  '/content/train/cat.7504.jpg',
#  '/content/train/dog.2918.jpg',
#  '/content/train/dog.4816.jpg',
#  '/content/train/dog.519.jpg',
#  '/content/train/cat.3600.jpg',
#  '/content/train/dog.11642.jpg',
#  '/content/train/cat.6855.jpg',
#  '/content/train/cat.9058.jpg',
#  '/content/train/dog.6593.jpg',
#  '/content/train/cat.339.jpg',
#  '/content/train/dog.5337.jpg',
#  '/content/train/cat.6334.jpg',
#  '/content/train/dog.2619.jpg',
#  '/content/train/dog.7291.jpg',
#  '/content/train/cat.1396.jpg',
#  '/content/train/dog.3149.jpg',
#  '/content/train/cat.8002.jpg',
#  '/content/train/dog.10894.jpg',
# ...
